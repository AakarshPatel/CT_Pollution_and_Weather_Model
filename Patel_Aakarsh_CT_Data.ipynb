# %%
import pandas as pd

# %%
import numpy as np

# %%
Data = pd.read_csv('/content/combined_file.csv')

# %%
Data.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Address', 'State', 'County', 'City', 'O3 Mean',
#        'O3 1st Max Value', 'O3 1st Max Hour', 'O3 AQI', 'CO Mean',
#        'CO 1st Max Value', 'CO 1st Max Hour', 'CO AQI', 'SO2 Mean',
#        'SO2 1st Max Value', 'SO2 1st Max Hour', 'SO2 AQI', 'NO2 Mean',
#        'NO2 1st Max Value', 'NO2 1st Max Hour', 'NO2 AQI', 'name', 'tempmax',
#        'tempmin', 'temp', 'feelslikemax', 'feelslikemin', 'feelslike', 'dew',
#        'humidity', 'precip', 'precipprob', 'precipcover', 'preciptype', 'snow',
#        'snowdepth', 'windgust', 'windspeed', 'winddir', 'sealevelpressure',
#        'cloudcover', 'visibility', 'solarradiation', 'solarenergy', 'uvindex',
#        'severerisk', 'sunrise', 'sunset', 'moonphase', 'conditions',
#        'description', 'icon', 'stations'],
#       dtype='object')

# %%
Data.head()
# Out:
#    Unnamed: 0        Date                                  Address  \
# 0         0.0  2000-01-01  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 1       348.0  2000-01-01        2857 N MILLER RD-S SCOTTSDALE STN
# 2       533.0  2000-01-01                 1237 S. BEVERLY , TUCSON
# 3       880.0  2000-01-01                   2956-A TREAT BOULEVARD
# 4      1243.0  2000-01-01                    5551 BETHEL ISLAND RD
#
#         State        County           City   O3 Mean  O3 1st Max Value  \
# 0     Arizona      Maricopa        Phoenix  0.019765             0.040
# 1     Arizona      Maricopa     Scottsdale  0.021059             0.039
# 2     Arizona          Pima         Tucson  0.020824             0.039
# 3  California  Contra Costa        Concord  0.019412             0.029
# 4  California  Contra Costa  Bethel Island  0.019059             0.022
#
#    O3 1st Max Hour  O3 AQI  ...  solarenergy  uvindex  severerisk  \
# ...

# %%
Data.tail(
)
# Out:
#         Unnamed: 0        Date                               Address  \
# 135222    118843.0  2005-10-26            583 W. 10TH ST., PITTSBURG
# 135223    119195.0  2005-10-26   1029 ETHEL ST, CALEXICO HIGH SCHOOL
# 135224    119555.0  2005-10-26             228 W. PALM AVE., BURBANK
# 135225    119910.0  2005-10-26           1630 N MAIN ST, LOS ANGELES
# 135226    120275.0  2005-10-26  3648 N. LONG BEACH BLVD., LONG BEACH
#
#              State        County         City   O3 Mean  O3 1st Max Value  \
# 135222  California  Contra Costa    Pittsburg  0.024118             0.027
# 135223  California      Imperial     Calexico  0.021235             0.046
# 135224  California   Los Angeles      Burbank  0.007824             0.016
# 135225  California   Los Angeles  Los Angeles  0.008353             0.014
# 135226  California   Los Angeles   Long Beach  0.017353             0.027
#
#         O3 1st Max Hour  O3 AQI  ...  solarenergy  uvindex  severerisk  \
# ...

# %%
Data.shape
# Out:
# (135227, 54)

# %%
Data.isnull().sum()
# Out:
# Unnamed: 0                0
# Date                      0
# Address                   0
# State                     0
# County                    0
# City                      0
# O3 Mean                   0
# O3 1st Max Value          0
# O3 1st Max Hour           0
# O3 AQI                    0
# CO Mean                   0
# CO 1st Max Value          0
# CO 1st Max Hour           0
# CO AQI                    0
# SO2 Mean                  0
# SO2 1st Max Value         0
# SO2 1st Max Hour          0
# SO2 AQI                   0
# NO2 Mean                  0
# NO2 1st Max Value         0
# NO2 1st Max Hour          0
# NO2 AQI                   0
# name                      0
# tempmax                   0
# tempmin                   0
# temp                      0
# feelslikemax              0
# feelslikemin              0
# feelslike                 0
# dew                       0
# humidity                  0
# precip                    0
# precipprob                0
# ...

# %%
Data.info
# Out:
# <bound method DataFrame.info of         Unnamed: 0        Date                                  Address  \
# 0              0.0  2000-01-01  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 1            348.0  2000-01-01        2857 N MILLER RD-S SCOTTSDALE STN
# 2            533.0  2000-01-01                 1237 S. BEVERLY , TUCSON
# 3            880.0  2000-01-01                   2956-A TREAT BOULEVARD
# 4           1243.0  2000-01-01                    5551 BETHEL ISLAND RD
# ...            ...         ...                                      ...
# 135222    118843.0  2005-10-26               583 W. 10TH ST., PITTSBURG
# 135223    119195.0  2005-10-26      1029 ETHEL ST, CALEXICO HIGH SCHOOL
# 135224    119555.0  2005-10-26                228 W. PALM AVE., BURBANK
# 135225    119910.0  2005-10-26              1630 N MAIN ST, LOS ANGELES
# 135226    120275.0  2005-10-26     3648 N. LONG BEACH BLVD., LONG BEACH
#
# ...

# %%
Data.describe
# Out:
# <bound method NDFrame.describe of         Unnamed: 0        Date                                  Address  \
# 0              0.0  2000-01-01  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 1            348.0  2000-01-01        2857 N MILLER RD-S SCOTTSDALE STN
# 2            533.0  2000-01-01                 1237 S. BEVERLY , TUCSON
# 3            880.0  2000-01-01                   2956-A TREAT BOULEVARD
# 4           1243.0  2000-01-01                    5551 BETHEL ISLAND RD
# ...            ...         ...                                      ...
# 135222    118843.0  2005-10-26               583 W. 10TH ST., PITTSBURG
# 135223    119195.0  2005-10-26      1029 ETHEL ST, CALEXICO HIGH SCHOOL
# 135224    119555.0  2005-10-26                228 W. PALM AVE., BURBANK
# 135225    119910.0  2005-10-26              1630 N MAIN ST, LOS ANGELES
# 135226    120275.0  2005-10-26     3648 N. LONG BEACH BLVD., LONG BEACH
#
# ...
